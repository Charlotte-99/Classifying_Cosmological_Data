# %% [markdown]
# <a href="https://colab.research.google.com/github/Charlotte-99/Y3Project/blob/main/Multi_Classification_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developing a CNN to Classify Augmented CMB Maps with Different String Tensions
# This notebook is divided into three sections:
#
#
# 1.   Importing, formatting and creating the data
# 2.   Building a pipeline and creating a CNN model
# 3.   Analysing the results

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os

from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, \
Dropout, AveragePooling2D, BatchNormalization
from tensorflow.keras.models import Sequential
from matplotlib.colors import ListedColormap

# %%
# Change directory
os.chdir('drive/MyDrive/Project')

# %%
# Colour map
cmap = ListedColormap(np.loadtxt('planck_map.txt')/255.)

# %% [markdown]
# ## Handling the data
# Below, we import our 5000 CMB and 2700 string cutouts. The CMB cutouts were generated by extracting 20 cutouts from each of 250 full-sky maps, whereas the 2700 string cutouts were generated from 3 full-sky maps.
#
# These images have a resolution of 1.5 arcmin.

# %%
# Import cmb and string maps
cmb = np.load('cmb_5000_extracts_highres.npy')

string = np.concatenate([np.load('string_map_extracts_1_res_1_5.npy'),
                         np.load('string_map_extracts_2_res_1_5.npy'),
                         np.load('string_map_extracts_3_res_1_5.npy')])

# Add channel dimension
cmb = cmb[..., np.newaxis]
string = string[..., np.newaxis]

print(cmb.shape)
print(string.shape)
# Out:
# (5000, 200, 200, 1)
# (2700, 200, 200, 1)

# %% [markdown]
# We will split the data into two different groups:
#
#
# 1.   Training set - this will be used to train our model. This will use 2212 base CMB cutouts and 1896 string cutouts, so that each of the classes contains 316 samples.
#
# 2.   Validation set - this will be used during training to check performance on unseen maps. This will use 469 base CMB cutouts and 402 string cutouts, so each class will contain 67 samples.
#
# 3. Test set - this will be used as a final evaluation of our model's performance.  This will use 469 base CMB cutouts and 402 string cutouts, so each class will contain 67 samples.
#
# Note that this leaves 1850 samples from our original CMB dataset unused.
#
# We will use the following labelling convention:
# <center>
# $\begin{array}{|c|c|}\hline
# \text{map label} & \alpha\\\hline
# 0 & 0\\
# 1 & 5 \times 10^-7\\
# 2 & 1 \times 10^-6\\
# 3 & 2 \times 10^-6\\
# 4 & 3 \times 10^-6\\
# 5 & 4 \times 10^-6\\
# 6 & 5 \times 10^-6\\\hline
# \end{array}$
# </center>
#
#
# First, we will shuffle our arrays.

# %%
# Shuffle cmb and string maps using different seeds.
np.random.shuffle(cmb)
np.random.shuffle(string)

# %% [markdown]
# Here, we create the training set by taking the first 1896 and 2212 images from the (now shuffled) string and cmb map arrays, respectively.

# %%
# Slice cmb array
X_train_cmb = cmb[:2212]

# Slice string array and also add placeholder string arrays for the cmb maps
# that we won't augment
nan_string = np.empty(shape=(316, 200, 200, 1))
nan_string[:] = np.NaN
X_train_string = np.concatenate([nan_string, string[:1896]])

# Label data
y_train = np.concatenate([np.zeros(316),
                          np.ones(316),
                          2*np.ones(316),
                          3*np.ones(316),
                          4*np.ones(316),
                          5*np.ones(316),
                          6*np.ones(316)]).astype(np.int64)

# Shuffle all arrays with same seed
np.random.RandomState(7).shuffle(X_train_cmb)
np.random.RandomState(7).shuffle(X_train_string)
np.random.RandomState(7).shuffle(y_train)

print(X_train_cmb.shape)
print(X_train_string.shape)
print(y_train.shape)
# Out:
# (2212, 200, 200, 1)
# (2212, 200, 200, 1)
# (2212,)

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
ax[0].imshow(X_train_cmb[0].reshape(200, 200), cmap=cmap)
ax[1].imshow(X_train_string[0].reshape(200, 200), cmap=cmap)
print(y_train[0])
# Out:
# 6

# %% [markdown]
# Then, we create the validation set. These arrays will not undergo augmentations on the fly, so we will create the augmented CMB maps through a straight addition with the by a multiplicative constant, $\alpha$.
#
# Our string maps' colour scale gives a measure of $\frac{\Theta}{GU}$. The multiplicative constant we use will give an indication of the string tension.

# %%
# Set up images for different classes
X_val = np.concatenate((cmb[2212:2279],
                        cmb[2279:2346] + 5e-7*string[1896:1963],
                        cmb[2346:2413] + 1e-6*string[1963:2030],
                        cmb[2413:2480] + 2e-6*string[2030:2097],
                        cmb[2480:2547] + 3e-6*string[2097:2164],
                        cmb[2547:2614] + 4e-6*string[2164:2231],
                        cmb[2614:2681] + 5e-6*string[2231:2298]))

# Label data
y_val = np.concatenate([np.zeros(67),
                          np.ones(67),
                          2*np.ones(67),
                          3*np.ones(67),
                          4*np.ones(67),
                          5*np.ones(67),
                          6*np.ones(67)]).astype(np.int64)

# Shuffle X_val, y_val with same seed
np.random.RandomState(14).shuffle(X_val)
np.random.RandomState(14).shuffle(y_val)

print(X_val.shape)
print(y_val.shape)
# Out:
# (469, 200, 200, 1)
# (469,)

# %% [markdown]
# We do the same and generate our test set.

# %%
# Set up images for different classes
X_test = np.concatenate((cmb[2681:2748],
                        cmb[2748:2815] + 5e-7*string[2298:2365],
                        cmb[2815:2882] + 1e-6*string[2365:2432],
                        cmb[2882:2949] + 2e-6*string[2432:2499],
                        cmb[2949:3016] + 3e-6*string[2499:2566],
                        cmb[3016:3083] + 4e-6*string[2566:2633],
                        cmb[3083:3150] + 5e-6*string[2633:]))

# Label data
y_test = np.concatenate([np.zeros(67),
                          np.ones(67),
                          2*np.ones(67),
                          3*np.ones(67),
                          4*np.ones(67),
                          5*np.ones(67),
                          6*np.ones(67)]).astype(np.int64)

# Shuffle X_val, y_val with same seed
np.random.RandomState(28).shuffle(X_test)
np.random.RandomState(28).shuffle(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (469, 200, 200, 1)
# (469,)

# %% [markdown]
# Below, we plot some images from our validation and test sets.

# %%
print(y_val[0])
print(y_val[47])

print(y_test[4])
print(y_test[1])

fig, axes = plt.subplots(2, 2, figsize=(8, 8))
axes[0, 0].imshow(X_val[0].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[0, 1].imshow(X_val[47].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[1, 0].imshow(X_test[4].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[1, 1].imshow(X_test[1].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
# Out:
# 6
# 1
# 5
# 2

# %% [markdown]
# ## Building the pipeline and CNN model
#
# In this section we will build the pipeline and CNN. First we introduce three functions: two types of batch normalisation functions and another function that will perform random string augmentations on the fly on our training set.

# %%
def batch_standardisation(maps, labels):
  epsilon = 1e-12
  mean, variance = tf.nn.moments(maps, axes=[0, 1, 2])
  denom = tf.math.sqrt(variance + epsilon)
  maps_standardised = (maps - mean)/denom
  return maps_standardised, labels

# %%
def batch_normalisation(maps, labels):
  min_val = tf.math.reduce_min(maps, axis=[0, 1, 2])
  max_val = tf.math.reduce_max(maps, axis=[0, 1, 2])
  denom = max_val - min_val
  maps_normalised = (maps - min_val)/denom
  return maps_normalised, labels

# %%
def choose_alpha(label):
  if label==1:
    return 5e-7
  elif label==2:
    return 1e-6
  elif label==3:
    return 2e-6
  elif label==4:
    return 3e-6
  elif label==5:
    return 4e-6
  elif label==6:
    return 5e-6
  elif label==0:
    return 0

def selective_string_maps(string_map, cmb_map, label):
  # label value
  N = np.int(label)
  shape = tf.convert_to_tensor(N).shape
  alpha = tf.py_function(choose_alpha, [N], Tout=tf.float64)
  alpha.set_shape(shape)

  # Transformation: rotate CMB map
  # Output: rotated CMB map and original label
  def rotation():
    cmb_rot = tf.image.rot90(cmb_map, tf.random.uniform(shape=[], minval=0,
                                          maxval=4, dtype=tf.int32))
    
    return cmb_rot, label

  # Transformation: introduce discontinuities to CMB map
  # Output: discontinuity map and original label
  def add_string():
    string_rot = tf.image.rot90(string_map, tf.random.uniform(shape=[], minval=0,
                                maxval=4, dtype=tf.int32))
    string_scaled = tf.multiply(string_rot, alpha)
    cmb_rot = tf.image.rot90(cmb_map, tf.random.uniform(shape=[], minval=0,
                            maxval=4, dtype=tf.int32))
    aug_cmb = tf.add(cmb_rot, string_scaled)
    return aug_cmb, label

  return tf.cond(N == 0, true_fn=rotation, false_fn=add_string)

# %%
check_ds = tf.data.Dataset.from_tensor_slices((X_train_string, X_train_cmb, y_train))
check_ds = check_ds.map(selective_string_maps)
check_ds = check_ds.shuffle(100)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))

for n, (map, label, a) in enumerate(check_ds.take(4)):
  ax.flat[n].imshow(np.array(map).reshape(200, 200), cmap=cmap, vmin=-300e-6,
                    vmax=300e-6)
  print(label.numpy())
  print(a.numpy())
# Out:
# 6
# 5e-06
# 5
# 4e-06
# 5
# 4e-06
# 0
# 0.0

# %% [markdown]
# We may now define our CNN model.

# %%
# Build model
def build_model():
  model = Sequential([Conv2D(32, (3, 3), padding='same', activation='relu'),
                      Conv2D(32, (3, 3), padding='same', activation='relu'),
                      MaxPooling2D(2),
                      Flatten(),
                      Dense(128, activation='relu'),
                      Dense(7, activation='softmax')
                      ])
  optimizer = tf.keras.optimizers.Adam(0.001)
  model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())
  return model

# %% [markdown]
# And finally we build our pipelines and test our CNN model. We can use either one of the batch functions.

# %%
# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train_string, X_train_cmb, y_train))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Train dataset pipeline
train_ds = train_ds.map(selective_string_maps)
train_ds = train_ds.shuffle(100)
train_ds = train_ds.batch(64)
train_ds = train_ds.map(batch_standardisation)
train_ds = train_ds.prefetch(1)

# Validation dataset pipeline
val_ds = val_ds.batch(64)
val_ds = val_ds.map(batch_standardisation)
val_ds = val_ds.prefetch(1)

# Test dataset pipeline
test_ds = test_ds.batch(64)
test_ds = test_ds.map(batch_standardisation)
test_ds = test_ds.prefetch(1)

model = build_model()

#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20,
                                            #restore_best_weights=True)

history = model.fit(train_ds, epochs=100, verbose=1, validation_data=val_ds)
print(model.summary())
# Out:
# Epoch 1/100
# 35/35 [==============================] - 5s 120ms/step - loss: 14.8296 - sparse_categorical_accuracy: 0.1457 - val_loss: 1.9467 - val_sparse_categorical_accuracy: 0.1620
# Epoch 2/100
# 35/35 [==============================] - 4s 116ms/step - loss: 1.9463 - sparse_categorical_accuracy: 0.1504 - val_loss: 1.9459 - val_sparse_categorical_accuracy: 0.1578
# Epoch 3/100
# 35/35 [==============================] - 4s 116ms/step - loss: 1.9458 - sparse_categorical_accuracy: 0.1393 - val_loss: 1.9456 - val_sparse_categorical_accuracy: 0.1471
# Epoch 4/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.9451 - sparse_categorical_accuracy: 0.1670 - val_loss: 1.9449 - val_sparse_categorical_accuracy: 0.1855
# Epoch 5/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.9443 - sparse_categorical_accuracy: 0.1471 - val_loss: 1.9435 - val_sparse_categorical_accuracy: 0.1748
# Epoch 6/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.9427 - sparse_categorical_accuracy: 0.1624 - val_loss: 1.9408 - val_sparse_categorical_accuracy: 0.1706
# Epoch 7/100
# 35/35 [==============================] - 4s 115ms/step - loss: 1.9383 - sparse_categorical_accuracy: 0.1581 - val_loss: 1.9356 - val_sparse_categorical_accuracy: 0.1620
# Epoch 8/100
# 35/35 [==============================] - 4s 115ms/step - loss: 1.9315 - sparse_categorical_accuracy: 0.1740 - val_loss: 1.9220 - val_sparse_categorical_accuracy: 0.1386
# Epoch 9/100
# 35/35 [==============================] - 4s 114ms/step - loss: 1.9135 - sparse_categorical_accuracy: 0.2070 - val_loss: 1.8723 - val_sparse_categorical_accuracy: 0.2175
# Epoch 10/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.8532 - sparse_categorical_accuracy: 0.2622 - val_loss: 1.7488 - val_sparse_categorical_accuracy: 0.2751
# Epoch 11/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.6847 - sparse_categorical_accuracy: 0.3438 - val_loss: 1.7820 - val_sparse_categorical_accuracy: 0.2154
# Epoch 12/100
# 35/35 [==============================] - 4s 115ms/step - loss: 1.6616 - sparse_categorical_accuracy: 0.3542 - val_loss: 1.5661 - val_sparse_categorical_accuracy: 0.3028
# Epoch 13/100
# 35/35 [==============================] - 4s 115ms/step - loss: 1.4133 - sparse_categorical_accuracy: 0.4612 - val_loss: 1.7543 - val_sparse_categorical_accuracy: 0.2473
# Epoch 14/100
# 35/35 [==============================] - 4s 117ms/step - loss: 1.3732 - sparse_categorical_accuracy: 0.4860 - val_loss: 1.7172 - val_sparse_categorical_accuracy: 0.2580
# Epoch 15/100
# 35/35 [==============================] - 4s 116ms/step - loss: 1.2133 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.5364 - val_sparse_categorical_accuracy: 0.3198
# Epoch 16/100
# 35/35 [==============================] - 4s 116ms/step - loss: 1.1251 - sparse_categorical_accuracy: 0.5820 - val_loss: 1.7629 - val_sparse_categorical_accuracy: 0.2687
# Epoch 17/100
# 35/35 [==============================] - 4s 116ms/step - loss: 1.0282 - sparse_categorical_accuracy: 0.6303 - val_loss: 1.6523 - val_sparse_categorical_accuracy: 0.3241
# Epoch 18/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.8479 - sparse_categorical_accuracy: 0.7287 - val_loss: 1.5287 - val_sparse_categorical_accuracy: 0.3603
# Epoch 19/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.6479 - sparse_categorical_accuracy: 0.8008 - val_loss: 1.6221 - val_sparse_categorical_accuracy: 0.3497
# Epoch 20/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.6269 - sparse_categorical_accuracy: 0.7896 - val_loss: 1.7719 - val_sparse_categorical_accuracy: 0.2921
# Epoch 21/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.6063 - sparse_categorical_accuracy: 0.8114 - val_loss: 1.7204 - val_sparse_categorical_accuracy: 0.3241
# Epoch 22/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.5256 - sparse_categorical_accuracy: 0.8363 - val_loss: 1.7589 - val_sparse_categorical_accuracy: 0.3518
# Epoch 23/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.3982 - sparse_categorical_accuracy: 0.8802 - val_loss: 1.7944 - val_sparse_categorical_accuracy: 0.3113
# Epoch 24/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.3635 - sparse_categorical_accuracy: 0.8879 - val_loss: 1.7399 - val_sparse_categorical_accuracy: 0.3518
# Epoch 25/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.3866 - sparse_categorical_accuracy: 0.8762 - val_loss: 1.8332 - val_sparse_categorical_accuracy: 0.2601
# Epoch 26/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.3403 - sparse_categorical_accuracy: 0.9112 - val_loss: 2.0623 - val_sparse_categorical_accuracy: 0.2495
# Epoch 27/100
# 35/35 [==============================] - 4s 115ms/step - loss: 0.2705 - sparse_categorical_accuracy: 0.9282 - val_loss: 2.2911 - val_sparse_categorical_accuracy: 0.2431
# Epoch 28/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.4980 - sparse_categorical_accuracy: 0.8405 - val_loss: 1.8989 - val_sparse_categorical_accuracy: 0.3326
# Epoch 29/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.2364 - sparse_categorical_accuracy: 0.9383 - val_loss: 2.0506 - val_sparse_categorical_accuracy: 0.2772
# Epoch 30/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.1817 - sparse_categorical_accuracy: 0.9523 - val_loss: 2.0244 - val_sparse_categorical_accuracy: 0.3262
# Epoch 31/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.1257 - sparse_categorical_accuracy: 0.9664 - val_loss: 2.1053 - val_sparse_categorical_accuracy: 0.3262
# Epoch 32/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9726 - val_loss: 2.2799 - val_sparse_categorical_accuracy: 0.3390
# Epoch 33/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0940 - sparse_categorical_accuracy: 0.9769 - val_loss: 2.1589 - val_sparse_categorical_accuracy: 0.3369
# Epoch 34/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.1160 - sparse_categorical_accuracy: 0.9733 - val_loss: 2.2114 - val_sparse_categorical_accuracy: 0.3412
# Epoch 35/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0805 - sparse_categorical_accuracy: 0.9801 - val_loss: 2.2068 - val_sparse_categorical_accuracy: 0.3412
# Epoch 36/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9841 - val_loss: 2.4255 - val_sparse_categorical_accuracy: 0.3070
# Epoch 37/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9836 - val_loss: 2.3914 - val_sparse_categorical_accuracy: 0.3539
# Epoch 38/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9849 - val_loss: 2.5439 - val_sparse_categorical_accuracy: 0.3348
# Epoch 39/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9877 - val_loss: 2.8033 - val_sparse_categorical_accuracy: 0.2623
# Epoch 40/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9785 - val_loss: 2.5777 - val_sparse_categorical_accuracy: 0.3134
# Epoch 41/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9952 - val_loss: 2.5628 - val_sparse_categorical_accuracy: 0.3518
# Epoch 42/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9923 - val_loss: 2.4574 - val_sparse_categorical_accuracy: 0.3262
# Epoch 43/100
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9960 - val_loss: 2.6076 - val_sparse_categorical_accuracy: 0.3539
# Epoch 44/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9958 - val_loss: 2.9326 - val_sparse_categorical_accuracy: 0.3305
# Epoch 45/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9909 - val_loss: 2.7475 - val_sparse_categorical_accuracy: 0.3390
# Epoch 46/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9903 - val_loss: 3.6605 - val_sparse_categorical_accuracy: 0.2601
# Epoch 47/100
# 35/35 [==============================] - 4s 115ms/step - loss: 0.1042 - sparse_categorical_accuracy: 0.9618 - val_loss: 2.4892 - val_sparse_categorical_accuracy: 0.3006
# Epoch 48/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9916 - val_loss: 2.5997 - val_sparse_categorical_accuracy: 0.2921
# Epoch 49/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9957 - val_loss: 2.7546 - val_sparse_categorical_accuracy: 0.3028
# Epoch 50/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9971 - val_loss: 2.9347 - val_sparse_categorical_accuracy: 0.2772
# Epoch 51/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9930 - val_loss: 2.7861 - val_sparse_categorical_accuracy: 0.3156
# Epoch 52/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9925 - val_loss: 2.7122 - val_sparse_categorical_accuracy: 0.3113
# Epoch 53/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9951 - val_loss: 2.7235 - val_sparse_categorical_accuracy: 0.3220
# Epoch 54/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9975 - val_loss: 2.9064 - val_sparse_categorical_accuracy: 0.3390
# Epoch 55/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9981 - val_loss: 2.8240 - val_sparse_categorical_accuracy: 0.3028
# Epoch 56/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9947 - val_loss: 2.7623 - val_sparse_categorical_accuracy: 0.3305
# Epoch 57/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9985 - val_loss: 2.7740 - val_sparse_categorical_accuracy: 0.3348
# Epoch 58/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9979 - val_loss: 2.9403 - val_sparse_categorical_accuracy: 0.3348
# Epoch 59/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9976 - val_loss: 2.8600 - val_sparse_categorical_accuracy: 0.2836
# Epoch 60/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9971 - val_loss: 2.9097 - val_sparse_categorical_accuracy: 0.3433
# Epoch 61/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9985 - val_loss: 2.9532 - val_sparse_categorical_accuracy: 0.3390
# Epoch 62/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9991 - val_loss: 2.9133 - val_sparse_categorical_accuracy: 0.3412
# Epoch 63/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9989 - val_loss: 2.7940 - val_sparse_categorical_accuracy: 0.3241
# Epoch 64/100
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9979 - val_loss: 2.9089 - val_sparse_categorical_accuracy: 0.2921
# Epoch 65/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9997 - val_loss: 2.8896 - val_sparse_categorical_accuracy: 0.3326
# Epoch 66/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9955 - val_loss: 3.2123 - val_sparse_categorical_accuracy: 0.2708
# Epoch 67/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9967 - val_loss: 2.9400 - val_sparse_categorical_accuracy: 0.3390
# Epoch 68/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9975 - val_loss: 3.0614 - val_sparse_categorical_accuracy: 0.3348
# Epoch 69/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9959 - val_loss: 2.9360 - val_sparse_categorical_accuracy: 0.3284
# Epoch 70/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9965 - val_loss: 2.9935 - val_sparse_categorical_accuracy: 0.3241
# Epoch 71/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0044 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.0701 - val_sparse_categorical_accuracy: 0.3241
# Epoch 72/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9984 - val_loss: 3.0846 - val_sparse_categorical_accuracy: 0.3092
# Epoch 73/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9978 - val_loss: 3.2724 - val_sparse_categorical_accuracy: 0.3177
# Epoch 74/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9998 - val_loss: 3.2959 - val_sparse_categorical_accuracy: 0.3241
# Epoch 75/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9997 - val_loss: 3.2182 - val_sparse_categorical_accuracy: 0.3177
# Epoch 76/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9996 - val_loss: 3.2502 - val_sparse_categorical_accuracy: 0.3305
# Epoch 77/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9988 - val_loss: 3.2057 - val_sparse_categorical_accuracy: 0.3284
# Epoch 78/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9990 - val_loss: 3.1998 - val_sparse_categorical_accuracy: 0.3284
# Epoch 79/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9997 - val_loss: 3.3492 - val_sparse_categorical_accuracy: 0.3134
# Epoch 80/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9985 - val_loss: 3.3396 - val_sparse_categorical_accuracy: 0.3284
# Epoch 81/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.4361 - val_sparse_categorical_accuracy: 0.3220
# Epoch 82/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 3.3676 - val_sparse_categorical_accuracy: 0.3390
# Epoch 83/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9988 - val_loss: 3.4527 - val_sparse_categorical_accuracy: 0.3454
# Epoch 84/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9999 - val_loss: 3.6904 - val_sparse_categorical_accuracy: 0.2814
# Epoch 85/100
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9955 - val_loss: 3.0430 - val_sparse_categorical_accuracy: 0.3241
# Epoch 86/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9984 - val_loss: 3.1097 - val_sparse_categorical_accuracy: 0.3369
# Epoch 87/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9988 - val_loss: 3.0754 - val_sparse_categorical_accuracy: 0.3220
# Epoch 88/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9993 - val_loss: 3.2135 - val_sparse_categorical_accuracy: 0.3326
# Epoch 89/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9994 - val_loss: 3.2751 - val_sparse_categorical_accuracy: 0.3134
# Epoch 90/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9999 - val_loss: 3.2269 - val_sparse_categorical_accuracy: 0.3177
# Epoch 91/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9970 - val_loss: 3.1998 - val_sparse_categorical_accuracy: 0.2964
# Epoch 92/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9980 - val_loss: 3.4052 - val_sparse_categorical_accuracy: 0.3284
# Epoch 93/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9959 - val_loss: 3.2278 - val_sparse_categorical_accuracy: 0.3305
# Epoch 94/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9999 - val_loss: 3.3380 - val_sparse_categorical_accuracy: 0.2942
# Epoch 95/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9964 - val_loss: 3.2457 - val_sparse_categorical_accuracy: 0.3454
# Epoch 96/100
# 35/35 [==============================] - 4s 118ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9985 - val_loss: 3.1097 - val_sparse_categorical_accuracy: 0.3220
# Epoch 97/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9994 - val_loss: 3.2980 - val_sparse_categorical_accuracy: 0.3433
# Epoch 98/100
# 35/35 [==============================] - 4s 116ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9973 - val_loss: 3.1386 - val_sparse_categorical_accuracy: 0.3198
# Epoch 99/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9918 - val_loss: 3.2525 - val_sparse_categorical_accuracy: 0.2964
# Epoch 100/100
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9934 - val_loss: 3.1828 - val_sparse_categorical_accuracy: 0.3177
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 200, 200, 32)      320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 200, 200, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 320000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               40960128
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 40,970,599
# Trainable params: 40,970,599
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
fig, ax = plt.subplots()
ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='val')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(history.history['sparse_categorical_accuracy'], label='train')
ax.plot(history.history['val_sparse_categorical_accuracy'], label='val')
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
plt.legend()

# %%
epsilon = 1e-10
mean = np.mean(X_val, axis=(0, 1, 2))
variance = np.var(X_val, axis=(0, 1, 2))

X_test_norm = (X_test - mean)/np.sqrt((variance + epsilon))

# %%
print(y_test[:50])
print(model.predict_classes(X_test_norm[:50]))
# Out:
# [3 2 4 2 5 6 0 4 6 2 5 0 3 6 3 4 0 5 0 0 1 0 3 0 2 1 1 6 5 3 1 3 2 4 6 1 4
#  4 5 5 6 5 0 0 5 1 3 3 0 5]
# [1 0 5 5 6 6 3 0 5 0 5 2 3 6 1 3 3 4 1 2 0 3 3 3 1 1 0 6 6 0 0 5 4 3 5 3 5
#  4 6 5 6 5 1 3 6 2 2 5 0 6]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
n = 3
print(y_test[n])
print(model.predict_classes(X_test_norm[n].reshape(1, 200, 200, 1)))
print(model.predict(X_test_norm[n].reshape(1, 200, 200, 1)))
# Out:
# 2
# [5]
# [[4.3637389e-01 4.8322661e-04 1.8526142e-02 1.1446472e-03 2.4717156e-05
#   5.4344594e-01 1.3473563e-06]]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
