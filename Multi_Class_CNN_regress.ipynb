# %% [markdown]
# # **Developing a CNN to Classify Augmented CMB Maps with Different String Tensions**
#
# This notebook is divided into three sections:
#
#
# 1.   Importing, formatting and creating the data
# 2.   Building a pipeline and creating a CNN model
# 3.   Analysing the results

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os

from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, \
Dropout, AveragePooling2D, BatchNormalization
from tensorflow.keras.models import Sequential
from matplotlib.colors import ListedColormap

# %%
# Mount google drive folder with .fits maps
from google.colab import drive
drive.mount('/content/drive')

# Change directory
os.chdir('drive/MyDrive/Project')
# Out:
# Mounted at /content/drive

# %%
# Colour map
cmap = ListedColormap(np.loadtxt('planck_map.txt')/255.)

# %% [markdown]
# # **Handling the data**
#
# Below, we import our 5000 CMB and 2700 string cutouts. The CMB cutouts were generated by extracting 20 cutouts from each of 250 full-sky maps, whereas the 2700 string cutouts were generated from 3 full-sky maps.
#
# These images have a resolution of 1.5 arcmin.

# %%
# Import cmb and string maps
cmb = np.load('cmb_5000_extracts_highres.npy')

string = np.concatenate([np.load('string_map_extracts_1_res_1_5.npy'),
                         np.load('string_map_extracts_2_res_1_5.npy'),
                         np.load('string_map_extracts_3_res_1_5.npy')])

# Add channel dimension
cmb = cmb[..., np.newaxis]
string = string[..., np.newaxis]

print(cmb.shape)
print(string.shape)
# Out:
# (5000, 200, 200, 1)
# (2700, 200, 200, 1)

# %% [markdown]
# We will split the data into two different groups:
#
#
#
# 1.   Training set - this will be used to train our model. This will use 2212 base CMB cutouts and 1896 string cutouts, so that each of the classes contains 316 samples.
# 2.   Validation set - this will be used during training to check performance on unseen maps. This will use 469 base CMB cutouts and 402 string cutouts, so each class will contain 67 samples.
# 3.   Test set - this will be used as a final evaluation of our model's performance. This will use 469 base CMB cutouts and 402 string cutouts, so each class will contain 67 samples.
#
# Note that this leaves 1850 samples from our original CMB dataset unused.
#
# We will use the following labelling convention:
#
# First, we will shuffle our arrays.

# %%
# Shuffle cmb and string maps using different seeds.
np.random.shuffle(cmb)
np.random.shuffle(string)

# %% [markdown]
# Here, we create the training set by taking the first 1896 and 2212 images from the (now shuffled) string and cmb map arrays, respectively.

# %%
# Slice cmb array
X_train_cmb = cmb[:2212]

# Slice string array and also add placeholder string arrays for the cmb maps
# that we won't augment
nan_string = np.empty(shape=(316, 200, 200, 1))
nan_string[:] = np.NaN
X_train_string = np.concatenate([nan_string, string[:1896]])

# Label data
y_train = np.concatenate([np.zeros(316),
                          np.ones(316),
                          2*np.ones(316),
                          3*np.ones(316),
                          4*np.ones(316),
                          5*np.ones(316),
                          6*np.ones(316)]).astype(np.int64)

# Alpha vlaues
alpha_train = np.concatenate([[0]*316, [5e-7]*316, [1e-6]*316, [2e-6]*316,
                             [3e-6]*316, [4e-6]*316, [5e-6]*316])

# Shuffle all arrays with same seed
np.random.RandomState(7).shuffle(X_train_cmb)
np.random.RandomState(7).shuffle(X_train_string)
np.random.RandomState(7).shuffle(y_train)
np.random.RandomState(7).shuffle(alpha_train)

print(X_train_cmb.shape)
print(X_train_string.shape)
print(y_train.shape)
print(alpha_train.shape)

print(y_train[:20])
print(alpha_train[:20])
# Out:
# (2212, 200, 200, 1)
# (2212, 200, 200, 1)
# (2212,)
# (2212,)
# [6 4 1 2 2 4 0 3 6 6 2 3 0 6 1 1 3 4 3 5]
# [5.e-06 3.e-06 5.e-07 1.e-06 1.e-06 3.e-06 0.e+00 2.e-06 5.e-06 5.e-06
#  1.e-06 2.e-06 0.e+00 5.e-06 5.e-07 5.e-07 2.e-06 3.e-06 2.e-06 4.e-06]

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
ax[0].imshow(X_train_cmb[0].reshape(200, 200), cmap=cmap)
ax[1].imshow(X_train_string[0].reshape(200, 200), cmap=cmap)
print(y_train[0])
# Out:
# 6

# %% [markdown]
# Then, we create the validation set. These arrays will not undergo augmentations on the fly, so we will create the augmented CMB maps through a straight addition with the by a multiplicative constant, $\alpha$.
#
# Our string maps' colour scale gives a measure of $\frac{\Theta}{GU}$. The multiplicative constant we use will give an indication of the string tension.

# %%
# Set up images for different classes
X_val = np.concatenate((cmb[2212:2279],
                        cmb[2279:2346] + 5e-7*string[1896:1963],
                        cmb[2346:2413] + 1e-6*string[1963:2030],
                        cmb[2413:2480] + 2e-6*string[2030:2097],
                        cmb[2480:2547] + 3e-6*string[2097:2164],
                        cmb[2547:2614] + 4e-6*string[2164:2231],
                        cmb[2614:2681] + 5e-6*string[2231:2298]))

# Label data
y_val = np.concatenate([np.zeros(67),
                          np.ones(67),
                          2*np.ones(67),
                          3*np.ones(67),
                          4*np.ones(67),
                          5*np.ones(67),
                          6*np.ones(67)]).astype(np.int64)

# Shuffle X_val, y_val with same seed
np.random.RandomState(14).shuffle(X_val)
np.random.RandomState(14).shuffle(y_val)

print(X_val.shape)
print(y_val.shape)
# Out:
# (469, 200, 200, 1)
# (469,)

# %% [markdown]
# We do the same and generate our test set.

# %%
# Set up images for different classes
X_test = np.concatenate((cmb[2681:2748],
                        cmb[2748:2815] + 5e-7*string[2298:2365],
                        cmb[2815:2882] + 1e-6*string[2365:2432],
                        cmb[2882:2949] + 2e-6*string[2432:2499],
                        cmb[2949:3016] + 3e-6*string[2499:2566],
                        cmb[3016:3083] + 4e-6*string[2566:2633],
                        cmb[3083:3150] + 5e-6*string[2633:]))

# Label data
y_test = np.concatenate([np.zeros(67),
                          np.ones(67),
                          2*np.ones(67),
                          3*np.ones(67),
                          4*np.ones(67),
                          5*np.ones(67),
                          6*np.ones(67)]).astype(np.int64)

# Shuffle X_val, y_val with same seed
np.random.RandomState(28).shuffle(X_test)
np.random.RandomState(28).shuffle(y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# (469, 200, 200, 1)
# (469,)

# %% [markdown]
# Below, we plot some images from our validation and test sets.

# %%
print(y_val[0])
print(y_val[47])

print(y_test[4])
print(y_test[1])

fig, axes = plt.subplots(2, 2, figsize=(8, 8))
axes[0, 0].imshow(X_val[0].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[0, 1].imshow(X_val[47].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[1, 0].imshow(X_test[4].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
axes[1, 1].imshow(X_test[1].reshape(200, 200), cmap=cmap,
                  vmin=-300e-6, vmax=300e-6)
# Out:
# 6
# 1
# 5
# 2

# %% [markdown]
# # **Building the pipeline and CNN model**
#
# In this section we will build the pipeline and CNN. First we introduce three functions: two types of batch normalisation functions and another function that will perform random string augmentations on the fly on our training set.

# %%
def batch_standardisation(maps, labels):
  epsilon = 1e-10
  mean, variance = tf.nn.moments(maps, axes=[0, 1, 2])
  denom = tf.math.sqrt(variance + epsilon)
  maps_standardised = (maps - mean)/denom
  return maps_standardised, labels

# %%
def batch_normalisation(maps, labels):
  min_val = tf.math.reduce_min(maps, axis=[0, 1, 2])
  max_val = tf.math.reduce_max(maps, axis=[0, 1, 2])
  denom = max_val - min_val
  maps_normalised = (maps - min_val)/denom
  return maps_normalised, labels

# %%
def selective_string_maps(string_map, cmb_map, label, alpha):
  # label value
  N = np.int(label)

  # Transformation: rotate CMB map
  # Output: rotated CMB map and original label
  def rotation():
    cmb_rot = tf.image.rot90(cmb_map, tf.random.uniform(shape=[], minval=0,
                                          maxval=4, dtype=tf.int32))
    
    return cmb_rot, label

  # Transformation: introduce discontinuities to CMB map
  # Output: discontinuity map and original label
  def add_string():
    string_rot = tf.image.rot90(string_map, tf.random.uniform(shape=[], minval=0,
                                maxval=4, dtype=tf.int32))
    string_scaled = tf.multiply(string_rot, alpha)
    cmb_rot = tf.image.rot90(cmb_map, tf.random.uniform(shape=[], minval=0,
                            maxval=4, dtype=tf.int32))
    aug_cmb = tf.add(cmb_rot, string_scaled)
    return aug_cmb, label

  return tf.cond(N == 0, true_fn=rotation, false_fn=add_string)

# %% [markdown]
# We may now define our CNN model.

# %%
# Build model
def build_model():
  model = Sequential([Conv2D(32, (3, 3), padding='same', activation='relu'),
                      Conv2D(32, (3, 3), padding='same', activation='relu'),
                      Conv2D(32, (3, 3), padding='same', activation='relu'),
                      Conv2D(32, (3, 3), padding='same', activation='relu'),
                      MaxPooling2D(2),
                      Flatten(),
                      Dense(128, activation='relu'),
                      Dense(1)
                      ])
  optimizer = tf.keras.optimizers.Adam(0.001)
  model.compile(optimizer=optimizer,
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())
  return model

# %% [markdown]
# And finally we build our pipelines and test our CNN model. We can use either one of the batch functions.

# %%
# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train_string, X_train_cmb,
                                               y_train, alpha_train))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Train dataset pipeline
train_ds = train_ds.map(selective_string_maps)
train_ds = train_ds.shuffle(100)
train_ds = train_ds.batch(64)
train_ds = train_ds.map(batch_standardisation)
train_ds = train_ds.prefetch(1)

# Validation dataset pipeline
val_ds = val_ds.batch(64)
val_ds = val_ds.map(batch_standardisation)
val_ds = val_ds.prefetch(1)

# Test dataset pipeline
test_ds = test_ds.batch(64)
test_ds = test_ds.map(batch_standardisation)
test_ds = test_ds.prefetch(1)

model = build_model()

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20,
                                            restore_best_weights=True)

history = model.fit(train_ds, epochs=100, verbose=1, validation_data=val_ds,
                    callbacks=[callback])
print(model.summary())
# Out:
# Epoch 1/100
# 35/35 [==============================] - 9s 226ms/step - loss: 144.9232 - sparse_categorical_accuracy: 0.1414 - val_loss: 3.6077 - val_sparse_categorical_accuracy: 0.1429
# Epoch 2/100
# 35/35 [==============================] - 8s 223ms/step - loss: 3.5070 - sparse_categorical_accuracy: 0.1396 - val_loss: 3.2449 - val_sparse_categorical_accuracy: 0.1429
# Epoch 3/100
# 35/35 [==============================] - 8s 225ms/step - loss: 3.4451 - sparse_categorical_accuracy: 0.1403 - val_loss: 3.2147 - val_sparse_categorical_accuracy: 0.1429
# Epoch 4/100
# 35/35 [==============================] - 8s 227ms/step - loss: 3.3667 - sparse_categorical_accuracy: 0.1380 - val_loss: 3.1739 - val_sparse_categorical_accuracy: 0.1429
# Epoch 5/100
# 35/35 [==============================] - 8s 232ms/step - loss: 3.3864 - sparse_categorical_accuracy: 0.1427 - val_loss: 3.1117 - val_sparse_categorical_accuracy: 0.1429
# Epoch 6/100
# 35/35 [==============================] - 8s 230ms/step - loss: 3.2623 - sparse_categorical_accuracy: 0.1417 - val_loss: 3.1143 - val_sparse_categorical_accuracy: 0.1429
# Epoch 7/100
# 35/35 [==============================] - 8s 233ms/step - loss: 3.2491 - sparse_categorical_accuracy: 0.1402 - val_loss: 2.9553 - val_sparse_categorical_accuracy: 0.1429
# Epoch 8/100
# 35/35 [==============================] - 8s 234ms/step - loss: 3.1081 - sparse_categorical_accuracy: 0.1418 - val_loss: 2.8629 - val_sparse_categorical_accuracy: 0.1429
# Epoch 9/100
# 35/35 [==============================] - 9s 237ms/step - loss: 2.9232 - sparse_categorical_accuracy: 0.1400 - val_loss: 3.0057 - val_sparse_categorical_accuracy: 0.1429
# Epoch 10/100
# 35/35 [==============================] - 9s 238ms/step - loss: 2.9915 - sparse_categorical_accuracy: 0.1413 - val_loss: 2.9284 - val_sparse_categorical_accuracy: 0.1429
# Epoch 11/100
# 35/35 [==============================] - 9s 241ms/step - loss: 2.6648 - sparse_categorical_accuracy: 0.1421 - val_loss: 1.9186 - val_sparse_categorical_accuracy: 0.1429
# Epoch 12/100
# 35/35 [==============================] - 9s 243ms/step - loss: 2.0045 - sparse_categorical_accuracy: 0.1412 - val_loss: 1.5619 - val_sparse_categorical_accuracy: 0.1429
# Epoch 13/100
# 35/35 [==============================] - 9s 246ms/step - loss: 1.8187 - sparse_categorical_accuracy: 0.1363 - val_loss: 1.2322 - val_sparse_categorical_accuracy: 0.1429
# Epoch 14/100
# 35/35 [==============================] - 9s 247ms/step - loss: 1.3773 - sparse_categorical_accuracy: 0.1438 - val_loss: 1.7430 - val_sparse_categorical_accuracy: 0.1429
# Epoch 15/100
# 35/35 [==============================] - 9s 247ms/step - loss: 1.3278 - sparse_categorical_accuracy: 0.1400 - val_loss: 1.4816 - val_sparse_categorical_accuracy: 0.1429
# Epoch 16/100
# 35/35 [==============================] - 9s 247ms/step - loss: 1.3902 - sparse_categorical_accuracy: 0.1400 - val_loss: 1.0950 - val_sparse_categorical_accuracy: 0.1429
# Epoch 17/100
# 35/35 [==============================] - 9s 245ms/step - loss: 1.1628 - sparse_categorical_accuracy: 0.1406 - val_loss: 1.0881 - val_sparse_categorical_accuracy: 0.1429
# Epoch 18/100
# 35/35 [==============================] - 9s 243ms/step - loss: 1.1335 - sparse_categorical_accuracy: 0.1434 - val_loss: 1.2849 - val_sparse_categorical_accuracy: 0.1429
# Epoch 19/100
# 35/35 [==============================] - 9s 242ms/step - loss: 1.3011 - sparse_categorical_accuracy: 0.1442 - val_loss: 1.1812 - val_sparse_categorical_accuracy: 0.1429
# Epoch 20/100
# 35/35 [==============================] - 9s 243ms/step - loss: 1.2436 - sparse_categorical_accuracy: 0.1386 - val_loss: 1.0439 - val_sparse_categorical_accuracy: 0.1429
# Epoch 21/100
# 35/35 [==============================] - 9s 243ms/step - loss: 1.0958 - sparse_categorical_accuracy: 0.1398 - val_loss: 1.2261 - val_sparse_categorical_accuracy: 0.1429
# Epoch 22/100
# 35/35 [==============================] - 9s 243ms/step - loss: 1.0347 - sparse_categorical_accuracy: 0.1400 - val_loss: 1.4769 - val_sparse_categorical_accuracy: 0.1429
# Epoch 23/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.1478 - sparse_categorical_accuracy: 0.1403 - val_loss: 1.4386 - val_sparse_categorical_accuracy: 0.1429
# Epoch 24/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.1437 - sparse_categorical_accuracy: 0.1414 - val_loss: 1.0153 - val_sparse_categorical_accuracy: 0.1429
# Epoch 25/100
# 35/35 [==============================] - 9s 245ms/step - loss: 1.0695 - sparse_categorical_accuracy: 0.1393 - val_loss: 1.0331 - val_sparse_categorical_accuracy: 0.1429
# Epoch 26/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.4875 - sparse_categorical_accuracy: 0.1401 - val_loss: 1.2236 - val_sparse_categorical_accuracy: 0.1429
# Epoch 27/100
# 35/35 [==============================] - 9s 245ms/step - loss: 1.2418 - sparse_categorical_accuracy: 0.1426 - val_loss: 1.1258 - val_sparse_categorical_accuracy: 0.1429
# Epoch 28/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.4266 - sparse_categorical_accuracy: 0.1447 - val_loss: 1.2336 - val_sparse_categorical_accuracy: 0.1429
# Epoch 29/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.3394 - sparse_categorical_accuracy: 0.1404 - val_loss: 1.2854 - val_sparse_categorical_accuracy: 0.1429
# Epoch 30/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.1884 - sparse_categorical_accuracy: 0.1385 - val_loss: 1.1512 - val_sparse_categorical_accuracy: 0.1429
# Epoch 31/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.0287 - sparse_categorical_accuracy: 0.1413 - val_loss: 1.5848 - val_sparse_categorical_accuracy: 0.1429
# Epoch 32/100
# 35/35 [==============================] - 9s 243ms/step - loss: 1.2163 - sparse_categorical_accuracy: 0.1405 - val_loss: 1.1256 - val_sparse_categorical_accuracy: 0.1429
# Epoch 33/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.0274 - sparse_categorical_accuracy: 0.1437 - val_loss: 1.1815 - val_sparse_categorical_accuracy: 0.1429
# Epoch 34/100
# 35/35 [==============================] - 9s 246ms/step - loss: 1.1052 - sparse_categorical_accuracy: 0.1436 - val_loss: 1.3315 - val_sparse_categorical_accuracy: 0.1429
# Epoch 35/100
# 35/35 [==============================] - 9s 244ms/step - loss: 1.1969 - sparse_categorical_accuracy: 0.1419 - val_loss: 1.2924 - val_sparse_categorical_accuracy: 0.1429
# Epoch 36/100
# 35/35 [==============================] - 9s 246ms/step - loss: 1.0651 - sparse_categorical_accuracy: 0.1400 - val_loss: 0.9596 - val_sparse_categorical_accuracy: 0.1429
# Epoch 37/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.9334 - sparse_categorical_accuracy: 0.1405 - val_loss: 0.9769 - val_sparse_categorical_accuracy: 0.1429
# Epoch 38/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.9387 - sparse_categorical_accuracy: 0.1412 - val_loss: 1.4865 - val_sparse_categorical_accuracy: 0.1429
# Epoch 39/100
# 35/35 [==============================] - 9s 246ms/step - loss: 1.1519 - sparse_categorical_accuracy: 0.1414 - val_loss: 1.4534 - val_sparse_categorical_accuracy: 0.1429
# Epoch 40/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.9771 - sparse_categorical_accuracy: 0.1437 - val_loss: 1.3335 - val_sparse_categorical_accuracy: 0.1429
# Epoch 41/100
# 35/35 [==============================] - 9s 245ms/step - loss: 1.1457 - sparse_categorical_accuracy: 0.1424 - val_loss: 1.4905 - val_sparse_categorical_accuracy: 0.1429
# Epoch 42/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.9727 - sparse_categorical_accuracy: 0.1407 - val_loss: 0.9561 - val_sparse_categorical_accuracy: 0.1429
# Epoch 43/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.7779 - sparse_categorical_accuracy: 0.1425 - val_loss: 1.2880 - val_sparse_categorical_accuracy: 0.1429
# Epoch 44/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.7988 - sparse_categorical_accuracy: 0.1368 - val_loss: 1.1051 - val_sparse_categorical_accuracy: 0.1429
# Epoch 45/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.8914 - sparse_categorical_accuracy: 0.1379 - val_loss: 1.1752 - val_sparse_categorical_accuracy: 0.1429
# Epoch 46/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.7975 - sparse_categorical_accuracy: 0.1426 - val_loss: 0.9583 - val_sparse_categorical_accuracy: 0.1429
# Epoch 47/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.8810 - sparse_categorical_accuracy: 0.1441 - val_loss: 1.1046 - val_sparse_categorical_accuracy: 0.1429
# Epoch 48/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.8730 - sparse_categorical_accuracy: 0.1441 - val_loss: 1.3240 - val_sparse_categorical_accuracy: 0.1429
# Epoch 49/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.8877 - sparse_categorical_accuracy: 0.1411 - val_loss: 1.0502 - val_sparse_categorical_accuracy: 0.1429
# Epoch 50/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.7742 - sparse_categorical_accuracy: 0.1416 - val_loss: 1.1558 - val_sparse_categorical_accuracy: 0.1429
# Epoch 51/100
# 35/35 [==============================] - 9s 245ms/step - loss: 0.7434 - sparse_categorical_accuracy: 0.1389 - val_loss: 1.0325 - val_sparse_categorical_accuracy: 0.1429
# Epoch 52/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.7516 - sparse_categorical_accuracy: 0.1406 - val_loss: 1.2144 - val_sparse_categorical_accuracy: 0.1429
# Epoch 53/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.8255 - sparse_categorical_accuracy: 0.1400 - val_loss: 0.9989 - val_sparse_categorical_accuracy: 0.1429
# Epoch 54/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.6352 - sparse_categorical_accuracy: 0.1440 - val_loss: 1.0422 - val_sparse_categorical_accuracy: 0.1429
# Epoch 55/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.6451 - sparse_categorical_accuracy: 0.1365 - val_loss: 0.9114 - val_sparse_categorical_accuracy: 0.1429
# Epoch 56/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5737 - sparse_categorical_accuracy: 0.1408 - val_loss: 0.9005 - val_sparse_categorical_accuracy: 0.1429
# Epoch 57/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.6262 - sparse_categorical_accuracy: 0.1435 - val_loss: 0.8829 - val_sparse_categorical_accuracy: 0.1429
# Epoch 58/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5908 - sparse_categorical_accuracy: 0.1416 - val_loss: 0.8999 - val_sparse_categorical_accuracy: 0.1429
# Epoch 59/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.5371 - sparse_categorical_accuracy: 0.1386 - val_loss: 0.9452 - val_sparse_categorical_accuracy: 0.1429
# Epoch 60/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.6584 - sparse_categorical_accuracy: 0.1410 - val_loss: 0.8990 - val_sparse_categorical_accuracy: 0.1429
# Epoch 61/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.6395 - sparse_categorical_accuracy: 0.1396 - val_loss: 0.9917 - val_sparse_categorical_accuracy: 0.1429
# Epoch 62/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.7404 - sparse_categorical_accuracy: 0.1403 - val_loss: 0.9255 - val_sparse_categorical_accuracy: 0.1429
# Epoch 63/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.5479 - sparse_categorical_accuracy: 0.1434 - val_loss: 0.8634 - val_sparse_categorical_accuracy: 0.1429
# Epoch 64/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5108 - sparse_categorical_accuracy: 0.1428 - val_loss: 0.9007 - val_sparse_categorical_accuracy: 0.1429
# Epoch 65/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.5146 - sparse_categorical_accuracy: 0.1442 - val_loss: 0.8724 - val_sparse_categorical_accuracy: 0.1429
# Epoch 66/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4937 - sparse_categorical_accuracy: 0.1429 - val_loss: 0.8469 - val_sparse_categorical_accuracy: 0.1429
# Epoch 67/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5967 - sparse_categorical_accuracy: 0.1431 - val_loss: 0.8409 - val_sparse_categorical_accuracy: 0.1429
# Epoch 68/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4960 - sparse_categorical_accuracy: 0.1398 - val_loss: 0.8382 - val_sparse_categorical_accuracy: 0.1429
# Epoch 69/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4370 - sparse_categorical_accuracy: 0.1385 - val_loss: 0.9590 - val_sparse_categorical_accuracy: 0.1429
# Epoch 70/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5333 - sparse_categorical_accuracy: 0.1379 - val_loss: 0.9221 - val_sparse_categorical_accuracy: 0.1429
# Epoch 71/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4381 - sparse_categorical_accuracy: 0.1379 - val_loss: 0.8286 - val_sparse_categorical_accuracy: 0.1429
# Epoch 72/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4185 - sparse_categorical_accuracy: 0.1386 - val_loss: 0.8067 - val_sparse_categorical_accuracy: 0.1429
# Epoch 73/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5343 - sparse_categorical_accuracy: 0.1367 - val_loss: 0.7848 - val_sparse_categorical_accuracy: 0.1429
# Epoch 74/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.5523 - sparse_categorical_accuracy: 0.1403 - val_loss: 0.8688 - val_sparse_categorical_accuracy: 0.1429
# Epoch 75/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4391 - sparse_categorical_accuracy: 0.1394 - val_loss: 0.9411 - val_sparse_categorical_accuracy: 0.1429
# Epoch 76/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.6759 - sparse_categorical_accuracy: 0.1403 - val_loss: 0.9400 - val_sparse_categorical_accuracy: 0.1429
# Epoch 77/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.5175 - sparse_categorical_accuracy: 0.1421 - val_loss: 0.8670 - val_sparse_categorical_accuracy: 0.1429
# Epoch 78/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4390 - sparse_categorical_accuracy: 0.1429 - val_loss: 0.8266 - val_sparse_categorical_accuracy: 0.1429
# Epoch 79/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.4129 - sparse_categorical_accuracy: 0.1432 - val_loss: 0.8031 - val_sparse_categorical_accuracy: 0.1429
# Epoch 80/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.1403 - val_loss: 0.8533 - val_sparse_categorical_accuracy: 0.1429
# Epoch 81/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.5735 - sparse_categorical_accuracy: 0.1447 - val_loss: 0.8437 - val_sparse_categorical_accuracy: 0.1429
# Epoch 82/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.4080 - sparse_categorical_accuracy: 0.1394 - val_loss: 0.7992 - val_sparse_categorical_accuracy: 0.1429
# Epoch 83/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3931 - sparse_categorical_accuracy: 0.1413 - val_loss: 0.8147 - val_sparse_categorical_accuracy: 0.1429
# Epoch 84/100
# 35/35 [==============================] - 9s 247ms/step - loss: 0.3945 - sparse_categorical_accuracy: 0.1398 - val_loss: 0.8480 - val_sparse_categorical_accuracy: 0.1429
# Epoch 85/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.3893 - sparse_categorical_accuracy: 0.1406 - val_loss: 0.7924 - val_sparse_categorical_accuracy: 0.1429
# Epoch 86/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.4335 - sparse_categorical_accuracy: 0.1418 - val_loss: 0.8083 - val_sparse_categorical_accuracy: 0.1429
# Epoch 87/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.4001 - sparse_categorical_accuracy: 0.1408 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.1429
# Epoch 88/100
# 35/35 [==============================] - 9s 246ms/step - loss: 0.3612 - sparse_categorical_accuracy: 0.1442 - val_loss: 0.7999 - val_sparse_categorical_accuracy: 0.1429
# Epoch 89/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3323 - sparse_categorical_accuracy: 0.1404 - val_loss: 0.7414 - val_sparse_categorical_accuracy: 0.1429
# Epoch 90/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.2984 - sparse_categorical_accuracy: 0.1413 - val_loss: 0.7246 - val_sparse_categorical_accuracy: 0.1429
# Epoch 91/100
# 35/35 [==============================] - 9s 249ms/step - loss: 0.3420 - sparse_categorical_accuracy: 0.1392 - val_loss: 0.8904 - val_sparse_categorical_accuracy: 0.1429
# Epoch 92/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3692 - sparse_categorical_accuracy: 0.1430 - val_loss: 0.7569 - val_sparse_categorical_accuracy: 0.1429
# Epoch 93/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3421 - sparse_categorical_accuracy: 0.1397 - val_loss: 0.7626 - val_sparse_categorical_accuracy: 0.1429
# Epoch 94/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3175 - sparse_categorical_accuracy: 0.1427 - val_loss: 0.7744 - val_sparse_categorical_accuracy: 0.1429
# Epoch 95/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.2902 - sparse_categorical_accuracy: 0.1412 - val_loss: 0.7743 - val_sparse_categorical_accuracy: 0.1429
# Epoch 96/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3466 - sparse_categorical_accuracy: 0.1422 - val_loss: 0.7432 - val_sparse_categorical_accuracy: 0.1429
# Epoch 97/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.2951 - sparse_categorical_accuracy: 0.1427 - val_loss: 0.9190 - val_sparse_categorical_accuracy: 0.1429
# Epoch 98/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.1405 - val_loss: 0.7467 - val_sparse_categorical_accuracy: 0.1429
# Epoch 99/100
# 35/35 [==============================] - 9s 248ms/step - loss: 0.3034 - sparse_categorical_accuracy: 0.1401 - val_loss: 0.7295 - val_sparse_categorical_accuracy: 0.1429
# Epoch 100/100
# 35/35 [==============================] - 9s 249ms/step - loss: 0.2799 - sparse_categorical_accuracy: 0.1424 - val_loss: 0.7177 - val_sparse_categorical_accuracy: 0.1429
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 200, 200, 32)      320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 200, 200, 32)      9248
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 200, 200, 32)      9248
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 200, 200, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 320000)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               40960128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 40,988,321
# Trainable params: 40,988,321
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
fig, ax = plt.subplots()
ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='val')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot(history.history['sparse_categorical_accuracy'], label='train')
ax.plot(history.history['val_sparse_categorical_accuracy'], label='val')
ax.set_xlabel('epoch')
ax.set_ylabel('accuracy')
plt.legend()

# %%
epsilon = 1e-10
mean = np.mean(X_val, axis=(0, 1, 2))
variance = np.var(X_val, axis=(0, 1, 2))

X_test_norm = (X_test - mean)/np.sqrt((variance + epsilon))

# %% [markdown]
# Not done this properly for now, but I've just been trying to see what it's predicting for the different values and I think they look kind of close? (ish)

# %%
print(y_test[:50])
# Out:
# [3 2 4 2 5 6 0 4 6 2 5 0 3 6 3 4 0 5 0 0 1 0 3 0 2 1 1 6 5 3 1 3 2 4 6 1 4
#  4 5 5 6 5 0 0 5 1 3 3 0 5]

# %%
predictions = model.predict(X_test_norm)
score = predictions.flatten()[7]    # correct result for regression

# %%
print(score)
# Out:
# 4.453583
